# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

warnings.filterwarnings('ignore')

# %%
INSTALLED__PAYMENTS_DATA_PATH = "../datasets/raw/installments_payments.csv"
IMAGES_PATH = "../images/"
OUTPUT_PATH = "../datasets/preprocess/"

# %%
df = pd.read_csv(INSTALLED__PAYMENTS_DATA_PATH)

display(df.head())
print("\n")
print(df.info())
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1054186      161674                     1.0                      6
# 1     1330831      151639                     0.0                     34
# 2     2085231      193053                     2.0                      1
# 3     2452527      199697                     1.0                      3
# 4     2714724      167756                     1.0                      2
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0          -1180.0             -1187.0        6948.360     6948.360
# 1          -2156.0             -2156.0        1716.525     1716.525
# 2            -63.0               -63.0       25425.000    25425.000
# 3          -2418.0             -2426.0       24350.130    24350.130
# 4          -1383.0             -1366.0        2165.040     2160.585
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13605401 entries, 0 to 13605400
# Data columns (total 8 columns):
# ...

# %%
df.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# count  1.360540e+07  1.360540e+07            1.360540e+07
# mean   1.903365e+06  2.784449e+05            8.566373e-01
# std    5.362029e+05  1.027183e+05            1.035216e+00
# min    1.000001e+06  1.000010e+05            0.000000e+00
# 25%    1.434191e+06  1.896390e+05            0.000000e+00
# 50%    1.896520e+06  2.786850e+05            1.000000e+00
# 75%    2.369094e+06  3.675300e+05            1.000000e+00
# max    2.843499e+06  4.562550e+05            1.780000e+02
#
#        NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# count           1.360540e+07     1.360540e+07        1.360250e+07
# mean            1.887090e+01    -1.042270e+03       -1.051114e+03
# std             2.666407e+01     8.009463e+02        8.005859e+02
# min             1.000000e+00    -2.922000e+03       -4.921000e+03
# 25%             4.000000e+00    -1.654000e+03       -1.662000e+03
# ...

# %%
(df.isna().sum() * 100 / len(df)).sort_values(ascending=False)
# Out:
# DAYS_ENTRY_PAYMENT        0.021352
# AMT_PAYMENT               0.021352
# SK_ID_PREV                0.000000
# SK_ID_CURR                0.000000
# NUM_INSTALMENT_VERSION    0.000000
# NUM_INSTALMENT_NUMBER     0.000000
# DAYS_INSTALMENT           0.000000
# AMT_INSTALMENT            0.000000
# dtype: float64

# %%
i = 1
for col in df.columns:
    if df[col].dtype == "object":
        print(f"{i}. {col} unique values -> {df[col].nunique()}")
        i += 1

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=['SK_ID_PREV', 'NUM_INSTALMENT_NUMBER', 'NUM_INSTALMENT_VERSION']).sum()
# Out:
# 653483

# %%
# Find an example with duplicated rows
dupes = df[df.duplicated(subset=['SK_ID_PREV', 'NUM_INSTALMENT_NUMBER', 'NUM_INSTALMENT_VERSION'], keep=False)]
dupes.sort_values(['SK_ID_PREV', 'NUM_INSTALMENT_NUMBER']).head(20)
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 1740975      1000005      176456                     1.0
# 2618814      1000005      176456                     1.0
# 9542169      1000015      315553                     1.0
# 10749262     1000015      315553                     1.0
# 251801       1000019      176905                     1.0
# 2320388      1000019      176905                     1.0
# 12717126     1000041      449214                     1.0
# 13477241     1000041      449214                     1.0
# 11801024     1000041      449214                     1.0
# 11802025     1000041      449214                     1.0
# 12929880     1000041      449214                     1.0
# 13447926     1000041      449214                     1.0
# 4250206      1000051      234782                     1.0
# 6197687      1000051      234782                     1.0
# 4706039      1000051      234782                     1.0
# ...

# %%
df.duplicated(subset=['SK_ID_PREV', 'NUM_INSTALMENT_NUMBER', 'NUM_INSTALMENT_VERSION', 'DAYS_ENTRY_PAYMENT', 'AMT_PAYMENT']).sum()
# Out:
# 0
