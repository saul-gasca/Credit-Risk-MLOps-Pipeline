# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

warnings.filterwarnings('ignore')

# %%
PREVIOUS__APPLICATION_DATA_PATH = "../datasets/raw/previous_application.csv"
IMAGES_PATH = "../images/"
OUTPUT_PATH = "../datasets/preprocess/"

# %%
df = pd.read_csv(PREVIOUS__APPLICATION_DATA_PATH)

display(df.head())
print("\n")
print(df.info())
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
df.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %%
(df.isna().sum() * 100 / len(df)).sort_values(ascending=False)
# Out:
# RATE_INTEREST_PRIVILEGED       99.643698
# RATE_INTEREST_PRIMARY          99.643698
# AMT_DOWN_PAYMENT               53.636480
# RATE_DOWN_PAYMENT              53.636480
# NAME_TYPE_SUITE                49.119754
# NFLAG_INSURED_ON_APPROVAL      40.298129
# DAYS_TERMINATION               40.298129
# DAYS_LAST_DUE                  40.298129
# DAYS_LAST_DUE_1ST_VERSION      40.298129
# DAYS_FIRST_DUE                 40.298129
# DAYS_FIRST_DRAWING             40.298129
# AMT_GOODS_PRICE                23.081773
# AMT_ANNUITY                    22.286665
# CNT_PAYMENT                    22.286366
# PRODUCT_COMBINATION             0.020716
# AMT_CREDIT                      0.000060
# NAME_YIELD_GROUP                0.000000
# NAME_PORTFOLIO                  0.000000
# NAME_SELLER_INDUSTRY            0.000000
# SELLERPLACE_AREA                0.000000
# CHANNEL_TYPE                    0.000000
# NAME_PRODUCT_TYPE               0.000000
# SK_ID_PREV                      0.000000
# ...

# %%
i = 1
for col in df.columns:
    if df[col].dtype == "object":
        print(f"{i}. {col} unique values -> {df[col].nunique()}")
        i += 1
# Out:
# 1. NAME_CONTRACT_TYPE unique values -> 4
# 2. WEEKDAY_APPR_PROCESS_START unique values -> 7
# 3. FLAG_LAST_APPL_PER_CONTRACT unique values -> 2
# 4. NAME_CASH_LOAN_PURPOSE unique values -> 25
# 5. NAME_CONTRACT_STATUS unique values -> 4
# 6. NAME_PAYMENT_TYPE unique values -> 4
# 7. CODE_REJECT_REASON unique values -> 9
# 8. NAME_TYPE_SUITE unique values -> 7
# 9. NAME_CLIENT_TYPE unique values -> 4
# 10. NAME_GOODS_CATEGORY unique values -> 28
# 11. NAME_PORTFOLIO unique values -> 5
# 12. NAME_PRODUCT_TYPE unique values -> 3
# 13. CHANNEL_TYPE unique values -> 8
# 14. NAME_SELLER_INDUSTRY unique values -> 11
# 15. NAME_YIELD_GROUP unique values -> 5
# 16. PRODUCT_COMBINATION unique values -> 17

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['SK_ID_PREV'].duplicated().sum()
# Out:
# 0

# %%
df[['DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION']].describe()
# Out:
#        DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  \
# count       997149.000000   997149.000000              997149.000000
# mean        342209.855039    13826.269337               33767.774054
# std          88916.115833    72444.869708              106857.034789
# min          -2922.000000    -2892.000000               -2801.000000
# 25%         365243.000000    -1628.000000               -1242.000000
# 50%         365243.000000     -831.000000                -361.000000
# 75%         365243.000000     -411.000000                 129.000000
# max         365243.000000   365243.000000              365243.000000
#
#        DAYS_LAST_DUE  DAYS_TERMINATION
# count  997149.000000     997149.000000
# mean    76582.403064      81992.343838
# std    149647.415123     153303.516729
# min     -2889.000000      -2874.000000
# 25%     -1314.000000      -1270.000000
# 50%      -537.000000       -499.000000
# 75%       -74.000000        -44.000000
# ...

# %%
(df['DAYS_FIRST_DRAWING'] == 365243).sum() / len(df) * 100
# Out:
# 55.94756121071911
